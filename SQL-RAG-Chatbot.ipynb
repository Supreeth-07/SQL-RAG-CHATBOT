# %% [markdown]
# # Topics
# ### Building a basic NL2SQL model
# ### Adding few-shot examples
# ### Dynamic few-shot example selection
# ### Dynamic relevant table selection (Large DB Isssue)
# ### Customizing prompts
# ### Adding memory to the chatbot so that it answers follow-up questions related to the database.

# %%
#DB conection details

import os
from dotenv import load_dotenv
load_dotenv()

db_user = os.getenv("db_user")
db_password = os.getenv("db_password")
db_host = os.getenv("db_host")
db_name = os.getenv("db_name")

# %% [markdown]
# # # Building a basic NL2SQL model

# %%
# DB Connection 

from langchain_community.utilities.sql_database import SQLDatabase

db = SQLDatabase.from_uri(
    database_uri="mssql+pyodbc://**?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"  ## update your conn str here
)

#SQLDatabase.from_uri(f"mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name}")

# %%
#Check DB info

print(db.dialect)
print("-"*100)
print(db.get_usable_table_names())
print("-"*100)
print(db.table_info)
# Out:
# mssql
# ----------------------------------------------------------------------------------------------------
# ['M_ACCESS', 'M_ACCESS_OBJ_ROLE_MAP', 'M_ACCESS_PANEL', 'M_ACCESS_ROLES', 'M_ACCESS_USR_ROLE_MAP', 'M_AUDITTRAIL', 'M_AUTHORITY_MATRIX1', 'M_BUSINESS_PLACE', 'M_COMPANY', 'M_COST_CENTER', 'M_DEPARTMENT', 'M_DESIGNATION', 'M_DOCUMENTS', 'M_EMPLOYEE', 'M_GL_CODES', 'M_GRADE', 'M_INVDATE_CAL', 'M_INVOICE_APPROVAL_MATRIX', 'M_INVOICE_DOCUMENTS', 'M_INVOICE_FI_MATRIX', 'M_INVOICE_MM_MATRIX', 'M_LOCATION', 'M_NATURE_OF_EXPENSE', 'M_PRIODICITY_OF_EXP', 'M_PROJECT_PURCHORG', 'M_REJECTION_REASON', 'M_SAP_FIN_DTL', 'M_TAX_CODE', 'M_TDS_TAXCODE', 'M_UNIQUENUMBER', 'M_USER', 'M_VENDOR', 'TEMP_INVOICE_HDR', 'TEMP_INVOICE_HDR1', 'T_ADVANCE_HDR', 'T_INVOICE_PAYMET_DTL', 'T_INVOICE_SUBMISSION_DTL', 'T_INVOICE_SUBMISSION_HDR', 'T_INVOICE_SUBMISSION_PODTL', 'T_LOGIN', 'T_MAILLOG', 'T_UPLOADINVOICE_MODIFICATIONDATA_HDR_ORG']
# ----------------------------------------------------------------------------------------------------
#
# CREATE TABLE [M_ACCESS] (
# 	[OBJ_ID] INTEGER NOT NULL,
# 	[OBJ_NAME] VARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[OBJ_PARENT_ID] VARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[OBJ_TYPE] VARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[OBJ_URL] VARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[OBJ_SEQ] INTEGER NOT NULL,
# 	[OBJ_LEVEL] VARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[RELATIVE_NAME] VARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[DELETED_YN] VARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[PANEL_ID] INTEGER NULL,
# 	[PROCESS_NAME] VARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FK_CLIENTID] INTEGER NULL,
# 	CONSTRAINT [PK_M_ACCESS_OBJ] PRIMARY KEY ([OBJ_ID])
# )
#
# /*
# 3 rows from M_ACCESS table:
# OBJ_ID	OBJ_NAME	OBJ_PARENT_ID	OBJ_TYPE	OBJ_URL	OBJ_SEQ	OBJ_LEVEL	RELATIVE_NAME	DELETED_YN	PANEL_ID	PROCESS_NAME	FK_CLIENTID
# 1	Access Type Masters	0	L	None	1	1	Access Type Masters	N	2	None	1
# 2	Access Roles Masters	1	N	Masters/AccessMaster/Access_Roles.aspx	1	1	Access Roles Masters	N	2	None	1
# 3	Page Access To Role Master	1	N	Masters/AccessMaster/PageAccess_to_AccessRole.aspx	2	1	Page Access To Role Master	N	2	None	1
# */
#
#
# CREATE TABLE [M_ACCESS_OBJ_ROLE_MAP] (
# 	[PK_ACCESS_OBJ_ROLE_ID] BIGINT NOT NULL IDENTITY(1,1),
# 	[AMD_BY] VARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[AMD_DATE] DATETIME NOT NULL,
# 	[IS_ACTIVE] INTEGER NOT NULL,
# 	[ACCESS_ROLE_ID] INTEGER NOT NULL,
# 	[OBJECT_ID] INTEGER NOT NULL,
# 	[PANEL_ID] INTEGER NULL,
# 	[FK_CLIENTID] INTEGER NULL,
# 	CONSTRAINT [PK_M_ACCESS_OBJ_ROLE_MAP] PRIMARY KEY ([PK_ACCESS_OBJ_ROLE_ID])
# )
#
# /*
# 3 rows from M_ACCESS_OBJ_ROLE_MAP table:
# PK_ACCESS_OBJ_ROLE_ID	AMD_BY	AMD_DATE	IS_ACTIVE	ACCESS_ROLE_ID	OBJECT_ID	PANEL_ID	FK_CLIENTID
# 2	flologic1	2020-07-24 13:51:26.130000	1	1	7	3	1
# 3	flologic1	2020-07-24 13:51:26.157000	1	1	8	3	1
# 4	flologic1	2020-07-28 12:41:47.010000	1	1	5	1	1
# */
#
#
# CREATE TABLE [M_ACCESS_PANEL] (
# 	[PANE_ID] INTEGER NOT NULL,
# 	[PANE_DESC] VARCHAR(30) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[DISPLAY_SEQ] INTEGER NOT NULL,
# 	[PANE_TYPE] VARCHAR(30) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	CONSTRAINT [PK_M_ACCESS_PANEL] PRIMARY KEY ([PANE_ID])
# )
#
# /*
# 3 rows from M_ACCESS_PANEL table:
# PANE_ID	PANE_DESC	DISPLAY_SEQ	PANE_TYPE
# 1	Process	1	1
# 2	Masters	2	2
# 3	Reports	3	3
# */
#
#
# CREATE TABLE [M_ACCESS_ROLES] (
# 	[PK_ROLE_ID] BIGINT NOT NULL IDENTITY(1,1),
# 	[ROLE_NAME] VARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[AMD_BY] VARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[AMD_DATE] DATETIME NULL,
# 	[FK_CLIENTID] INTEGER NULL,
# 	CONSTRAINT [PK_M_ACCESS_ROLES] PRIMARY KEY ([PK_ROLE_ID])
# )
#
# /*
# 3 rows from M_ACCESS_ROLES table:
# PK_ROLE_ID	ROLE_NAME	IS_ACTIVE	AMD_BY	AMD_DATE	FK_CLIENTID
# 1	Portal Admin	1	flologic1	2020-07-09 15:16:54.370000	1
# 2	Initiator	1	flologic1	2020-09-19 09:45:44.460000	1
# 3	MIS Reports	1	BTS346	2020-10-24 11:57:49.557000	1
# */
#
#
# CREATE TABLE [M_ACCESS_USR_ROLE_MAP] (
# 	[PK_USER_ROLE_ACCESS_ID] BIGINT NOT NULL IDENTITY(1,1),
# 	[AMD_BY] VARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[AMD_DATE] DATETIME NOT NULL,
# 	[IS_ACTIVE] INTEGER NOT NULL,
# 	[USER_ADID] VARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[ACCESS_ROLE_ID] INTEGER NOT NULL,
# 	[FK_CLIENTID] INTEGER NULL,
# 	CONSTRAINT [PK_M_ACCESS_USR_ROLE_MAP] PRIMARY KEY ([PK_USER_ROLE_ACCESS_ID])
# )
#
# /*
# 3 rows from M_ACCESS_USR_ROLE_MAP table:
# PK_USER_ROLE_ACCESS_ID	AMD_BY	AMD_DATE	IS_ACTIVE	USER_ADID	ACCESS_ROLE_ID	FK_CLIENTID
# 306	BTS386	2021-02-08 10:10:56.580000	1	BTS4106	0	1
# 32278	BTS063	2023-02-17 16:06:04.133000	1	BTS515	8	1
# 36028	BTS063	2023-07-03 11:53:54.427000	1	BTS517	9	1
# */
#
#
# CREATE TABLE [M_AUDITTRAIL] (
# 	[PK_AUDIT_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[PROCESSID] INTEGER NULL,
# 	[INSTANCEID] INTEGER NULL,
# 	[STEPNAME] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[ACTION] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[REMARK] NVARCHAR(1000) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATEDBY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATEDDATE] DATETIME NULL,
# 	[PERFORMERTYPE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[ACTIONBYUSER] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[ACTIONDATE] DATETIME NULL,
# 	CONSTRAINT [PK_M_AUDITTRAIL] PRIMARY KEY ([PK_AUDIT_ID])
# )
#
# /*
# 3 rows from M_AUDITTRAIL table:
# PK_AUDIT_ID	PROCESSID	INSTANCEID	STEPNAME	ACTION	REMARK	CREATEDBY	CREATEDDATE	PERFORMERTYPE	ACTIONBYUSER	ACTIONDATE
# 1	3	41	INVOICE SUBMISSION	SUBMIT	szdk	None	None	DATASLOT	flologic1	2020-08-13 18:15:04.220000
# 2	3	42	INVOICE SUBMISSION	SUBMIT	szdk	None	None	DATASLOT	flologic1	2020-08-13 18:17:07.297000
# 3	3	41	INVOICE APPROVAL	APPROVE	apr	None	None	DATASLOT	sanjeev.chopra	2020-08-13 18:26:46.237000
# */
#
#
# CREATE TABLE [M_AUTHORITY_MATRIX1] (
# 	[PK_AUTHORITY_MATRIX] INTEGER NOT NULL IDENTITY(1,1),
# 	[APPR_ID] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FROM_AMOUNT] NUMERIC(18, 2) NULL,
# 	[TO_AMOUNT] NUMERIC(18, 2) NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATED_DATE] DATETIME NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[FLAG] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	CONSTRAINT [PK_M_AUTHORITY_MATRIX1] PRIMARY KEY ([PK_AUTHORITY_MATRIX])
# )
#
# /*
# 3 rows from M_AUTHORITY_MATRIX1 table:
# PK_AUTHORITY_MATRIX	APPR_ID	FROM_AMOUNT	TO_AMOUNT	CREATED_BY	CREATED_DATE	IS_ACTIVE	FLAG
# 1	nitinbane.hgs	0.00	100000.00	667	2021-03-29 21:55:50.243000	1	0
# 2	BTS1050	100000.00	250000.00	667	2021-03-29 21:55:50.243000	1	0
# 3	BTS349	250001.00	1000000000.00	hgs003	2021-03-29 21:55:50.243000	1	0
# */
#
#
# CREATE TABLE [M_BUSINESS_PLACE] (
# 	[PK_BUSI_PLACE_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[Cl] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CoCd] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Business_Place] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Place_Name] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Tax_Number] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATION_DATE] DATETIME NULL,
# 	CONSTRAINT [PK_M_BUSINESS_PLACE] PRIMARY KEY ([PK_BUSI_PLACE_ID])
# )
#
# /*
# 3 rows from M_BUSINESS_PLACE table:
# PK_BUSI_PLACE_ID	Cl	CoCd	Business_Place	Place_Name	Tax_Number	IS_ACTIVE	CREATED_BY	CREATION_DATE
# 1	295	2000	01JK	Jammu and Kashmir		1	None	None
# 2	295	2000	02HP	Himachal Prdesh		1	None	None
# 3	295	2000	03PB	Punjab	03AADCP6815A1ZZ	1	None	None
# */
#
#
# CREATE TABLE [M_COMPANY] (
# 	[PK_COMPANY_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[COMPANY_NAME] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[COMPANY_DESC] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATED_DATE] DATETIME NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[FK_CLIENTID] INTEGER NULL,
# 	[COMPANY_ID] INTEGER NULL,
# 	CONSTRAINT [PK_M_COMPANY] PRIMARY KEY ([PK_COMPANY_ID])
# )
#
# /*
# 3 rows from M_COMPANY table:
# PK_COMPANY_ID	COMPANY_NAME	COMPANY_DESC	CREATED_BY	CREATED_DATE	IS_ACTIVE	FK_CLIENTID	COMPANY_ID
# 1	ONEOTT	ONEOTT	flologic1	2023-12-28 00:00:00	1	1	0
# */
#
#
# CREATE TABLE [M_COST_CENTER] (
# 	[PK_COST_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[COMPANY_CODE] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[COST_CENTER] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PROFIT_CENTER] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATION_DATE] DATETIME NULL,
# 	CONSTRAINT [PK_M_COST_CENTER] PRIMARY KEY ([PK_COST_ID])
# )
#
# /*
# 3 rows from M_COST_CENTER table:
# PK_COST_ID	COMPANY_CODE	COST_CENTER	PROFIT_CENTER	IS_ACTIVE	CREATED_BY	CREATION_DATE
# 1	NDL	ADESTR_CAB	ADGOLDSTAR	1	None	None
# 2	NDL	ADESTR_FIB	ADGOLDSTAR	1	None	None
# 3	NDL	ADESTR_INT	ADGOLDSTAR	1	None	None
# */
#
#
# CREATE TABLE [M_DEPARTMENT] (
# 	[PK_DEPARTMENT_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[DEPARTMENT_NAME] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DEPARTMENT_DESC] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATION_DATE] DATETIME NULL,
# 	[DEPARTMENT_HEAD] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FK_CLIENTID] INTEGER NULL,
# 	CONSTRAINT [PK_M_DEPARTMENT] PRIMARY KEY ([PK_DEPARTMENT_ID])
# )
#
# /*
# 3 rows from M_DEPARTMENT table:
# PK_DEPARTMENT_ID	DEPARTMENT_NAME	DEPARTMENT_DESC	IS_ACTIVE	CREATED_BY	CREATION_DATE	DEPARTMENT_HEAD	FK_CLIENTID
# 1	ONEOTT	ONEOTT	1	flologic1	2021-06-20 00:00:00	None	1
# 2	REVENUE	REVENUE	1	flologic1	2021-06-20 00:00:00	None	1
# 3	SAP_1&1 BROADBAND	SAP_1&1 BROADBAND	1	flologic1	2021-06-20 00:00:00	None	1
# */
#
#
# CREATE TABLE [M_DESIGNATION] (
# 	[PK_DESIGNATION_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[DESIGNATION_NAME] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DESIGNATION_DESC] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATION_DATE] DATETIME NULL,
# 	[FK_CLIENTID] INTEGER NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	CONSTRAINT [PK_M_DESIGNATION] PRIMARY KEY ([PK_DESIGNATION_ID])
# )
#
# /*
# 3 rows from M_DESIGNATION table:
# PK_DESIGNATION_ID	DESIGNATION_NAME	DESIGNATION_DESC	CREATED_BY	CREATION_DATE	FK_CLIENTID	IS_ACTIVE
# 1	A	SA	None	None	1	1
# */
#
#
# CREATE TABLE [M_DOCUMENTS] (
# 	[PK_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[OBJECT_NAME] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[OBJECT_VALUE] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FILENAME] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PATH] NVARCHAR(1000) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DESCRIPTION] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DOCUMENT_TYPE] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	CONSTRAINT [PK_M_DOCUMENTS] PRIMARY KEY ([PK_ID])
# )
#
# /*
# 3 rows from M_DOCUMENTS table:
# PK_ID	OBJECT_NAME	OBJECT_VALUE	FILENAME	PATH	DESCRIPTION	DOCUMENT_TYPE	CREATED_BY
# 1	INVOICESUBMISSION	BTS-FY-20-21-1	InvoiceVideoSpectrumOneottIntertainmentLimited.pdf	None	None	Invoice	None
# 2	INVOICESUBMISSION	BTS-FY-20-21-1	VideoSpectrumJan-June.pdf	None	None	Invoice backup	None
# 3	INVOICESUBMISSION	BTS-FY-20-21-2	BPCableInvoiceQ1Q22.pdf	None	None	Invoice	None
# */
#
#
# CREATE TABLE [M_EMPLOYEE] (
# 	[PK_EMP_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[AD_ID] NVARCHAR(200) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PASSWORD] NVARCHAR(1000) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMP_NAME] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMP_CODE] NVARCHAR(200) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MOBILE_NO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[ADDRESS] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAILID] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FK_DESIGNATION_ID] INTEGER NULL,
# 	[FK_BRANCH_ID] INTEGER NULL,
# 	[FK_DEPARTMENT_ID] INTEGER NULL,
# 	[FK_COMPANY_ID] INTEGER NULL,
# 	[DATE_JOINING] DATETIME NULL,
# 	[DATE_BIRTH] DATETIME NULL,
# 	[LAST_WORKING_DATE] DATETIME NULL,
# 	[FK_DIVISION_ID] INTEGER NULL,
# 	[FK_VERTICAL_ID] INTEGER NULL,
# 	[FK_COST_CENTER_ID] INTEGER NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATION_DATE] DATETIME NULL,
# 	[IFSCCODE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FK_GRADE_ID] INTEGER NULL,
# 	[ADMINREPORTING_TO] NVARCHAR(200) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FUNCTIONALREPORTING_TO] NVARCHAR(200) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[REGIONAL_HR] NVARCHAR(200) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FK_CLIENTID] INTEGER NULL,
# 	CONSTRAINT [PK_M_EMPLOYEE] PRIMARY KEY ([PK_EMP_ID])
# )
#
# /*
# 3 rows from M_EMPLOYEE table:
# PK_EMP_ID	AD_ID	PASSWORD	EMP_NAME	EMP_CODE	MOBILE_NO	ADDRESS	EMAILID	FK_DESIGNATION_ID	FK_BRANCH_ID	FK_DEPARTMENT_ID	FK_COMPANY_ID	DATE_JOINING	DATE_BIRTH	LAST_WORKING_DATE	FK_DIVISION_ID	FK_VERTICAL_ID	FK_COST_CENTER_ID	IS_ACTIVE	CREATED_BY	CREATION_DATE	IFSCCODE	FK_GRADE_ID	ADMINREPORTING_TO	FUNCTIONALREPORTING_TO	REGIONAL_HR	FK_CLIENTID
# 1	flologic1	bXngcZ071Ks3laC6BKkD5Q==	flologic sys	flologic1	94	address	arti.deshpande@flologicautomation.com	1	1	1	1	None	None	None	1	1	1	1	None	None	None	1	flologic1	flologic1	flologic1	1
# 2	rohit.singh	flx+0hxI2uF90eN3PqeIjg==	ROHIT SINGH	rohit.singh	None	None	rohit.singh@onebroadband.in	1	1	1	1	None	None	None	1	1	1	0	flologic1	2020-08-13 15:50:23.197000		1	flologic1	flologic1	flologic1	1
# 3	BTS346	GKSw36Pf6fBwUojKYf1FWg==	RAJENDRA CHAUDHARI	BTS346	1	address	rajendra.chaudhari@onebroadband.in	1	1	1	1	None	None	None	1	1	1	0	flologic1	2020-09-22 12:43:53.837000		1	flologic1	flologic1	flologic1	1
# */
#
#
# CREATE TABLE [M_GL_CODES] (
# 	[PK_GL_CODES_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[Type_Of_Service_Availed] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Capex_Opex] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[GL_Account] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[GL_Name] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATION_DATE] DATETIME NULL,
# 	CONSTRAINT [PK_M_GL_CODES] PRIMARY KEY ([PK_GL_CODES_ID])
# )
#
# /*
# 3 rows from M_GL_CODES table:
# PK_GL_CODES_ID	Type_Of_Service_Availed	Capex_Opex	GL_Account	GL_Name	IS_ACTIVE	CREATED_BY	CREATION_DATE
# 1	Courier charges	Opex	420002	COURIER CHGS.	1	None	None
# 2	Freight Inward	Opex	432020	FREIGHT INWARD	1	None	None
# 3	Freight Outward	Opex	432021	FREIGHT OUTWARD	1	None	None
# */
#
#
# CREATE TABLE [M_GRADE] (
# 	[PK_GRADE_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[GRADE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATION_DATE] DATETIME NULL,
# 	[FK_CLIENTID] INTEGER NULL,
# 	CONSTRAINT [PK_M_GRADE] PRIMARY KEY ([PK_GRADE_ID])
# )
#
# /*
# 3 rows from M_GRADE table:
# PK_GRADE_ID	GRADE	IS_ACTIVE	CREATED_BY	CREATION_DATE	FK_CLIENTID
# 1	A	1	None	None	1
# */
#
#
# CREATE TABLE [M_INVDATE_CAL] (
# 	[PK_INVOICEDATE_CAL] INTEGER NOT NULL IDENTITY(1,1),
# 	[INVDATE_CAL] INTEGER NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATION_DATE] DATETIME NULL,
# 	[FK_CLIENTID] INTEGER NULL,
# 	CONSTRAINT [PK_M_INVDATE_CAL] PRIMARY KEY ([PK_INVOICEDATE_CAL])
# )
#
# /*
# 3 rows from M_INVDATE_CAL table:
# PK_INVOICEDATE_CAL	INVDATE_CAL	IS_ACTIVE	CREATED_BY	CREATION_DATE	FK_CLIENTID
# 1	90	1	flologic1	2024-01-18 16:25:23	1
# */
#
#
# CREATE TABLE [M_INVOICE_APPROVAL_MATRIX] (
# 	[PK_INVOICE_APPR_MATRIX_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[FK_DEPT_ID] INTEGER NULL,
# 	[PURCH_ORG] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SEQ_NO] INTEGER NULL,
# 	[APPR_ID] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FROM_AMOUNT] NUMERIC(18, 2) NULL,
# 	[TO_AMOUNT] NUMERIC(18, 2) NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATED_DATE] DATETIME NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[LOC_ID] INTEGER NULL,
# 	CONSTRAINT [PK_M_INVOICE_APPROVAL_MATRIX] PRIMARY KEY ([PK_INVOICE_APPR_MATRIX_ID])
# )
#
# /*
# 3 rows from M_INVOICE_APPROVAL_MATRIX table:
# PK_INVOICE_APPR_MATRIX_ID	FK_DEPT_ID	PURCH_ORG	SEQ_NO	APPR_ID	FROM_AMOUNT	TO_AMOUNT	CREATED_BY	CREATED_DATE	IS_ACTIVE	LOC_ID
# 17	1	NOC	1	BTS1145	0.00	1000.00	BTS063	2025-04-28 11:23:22.443000	1	1
# 18	19	FACEBOOK	1	BTS082	0.00	1000.00	BTS063	2024-05-29 16:48:46.217000	1	1
# 20	19	FACEBOOK	3	BTS118	0.00	1000.00	BTS063	2024-05-29 16:48:46.227000	1	1
# */
#
#
# CREATE TABLE [M_INVOICE_DOCUMENTS] (
# 	[PK_DOC_ID] BIGINT NOT NULL IDENTITY(1,1),
# 	[DOC_PATH] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[USER_ID] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATED_AT] DATETIME NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[FILENAME] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	CONSTRAINT [PK_M_INVOICE_DOCUMENTS] PRIMARY KEY ([PK_DOC_ID])
# )
#
# /*
# 3 rows from M_INVOICE_DOCUMENTS table:
# PK_DOC_ID	DOC_PATH	USER_ID	CREATED_BY	CREATED_AT	IS_ACTIVE	FILENAME
# 1	C:\Flologic\Project\BTS\BTSPUBLISH\Data\UploadDocument\\flologic1\RTI-23-24-MH-269 Hinduja_UserName_	flologic1	flologic1	2023-12-28 17:58:09.340000	1	None
# 2	C:\Flologic\Project\BTS\BTSPUBLISH\Data\UploadDocument\\flologic1\HE-2324-216 - One OTT (1)_UserName	flologic1	flologic1	2023-12-29 10:10:40.177000	1	None
# 3	C:\Flologic\Project\BTS\BTSPUBLISH\Data\UploadDocument\\BTS517\ONEOTT Intertainment Ltd._DR527202728	BTS517	BTS517	2024-01-02 17:26:54.757000	1	None
# */
#
#
# CREATE TABLE [M_INVOICE_FI_MATRIX] (
# 	[PK_INVOICE_FI_MATRIX] INTEGER NOT NULL IDENTITY(1,1),
# 	[FK_DEPT_ID] INTEGER NULL,
# 	[PURCH_ORG] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[APPR_ID] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATED_DATE] DATETIME NULL,
# 	[PARAMETER_NAME] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	CONSTRAINT [PK_M_INVOICE_FI_MATRIX] PRIMARY KEY ([PK_INVOICE_FI_MATRIX])
# )
#
# /*
# 3 rows from M_INVOICE_FI_MATRIX table:
# PK_INVOICE_FI_MATRIX	FK_DEPT_ID	PURCH_ORG	APPR_ID	IS_ACTIVE	CREATED_BY	CREATED_DATE	PARAMETER_NAME
# 1	1	COMMISSION	hgs.accounts	1	flologic1	2021-06-20 00:00:00	FI BOOKING USER
# 2	1	DFW	hgs.accounts	0	flologic1	2021-06-20 00:00:00	FI BOOKING USER
# 3	1	FACEBOOK	hgs.accounts	0	flologic1	2021-06-20 00:00:00	FI BOOKING USER
# */
#
#
# CREATE TABLE [M_INVOICE_MM_MATRIX] (
# 	[PK_MMUSER_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[FK_DEPT_ID] INTEGER NULL,
# 	[PURCH_ORG] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[APPR_ID] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATED_DATE] DATETIME NULL,
# 	CONSTRAINT [PK_M_INVOICE_MM_MATRIX] PRIMARY KEY ([PK_MMUSER_ID])
# )
#
# /*
# 3 rows from M_INVOICE_MM_MATRIX table:
# PK_MMUSER_ID	FK_DEPT_ID	PURCH_ORG	APPR_ID	IS_ACTIVE	CREATED_BY	CREATED_DATE
#
# */
#
#
# CREATE TABLE [M_LOCATION] (
# 	[PK_LOC_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[LOCATION_NAME] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[LOCATION_CODE] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATION_DATE] DATETIME NULL,
# 	CONSTRAINT [PK_M_LOCATION] PRIMARY KEY ([PK_LOC_ID])
# )
#
# /*
# 3 rows from M_LOCATION table:
# PK_LOC_ID	LOCATION_NAME	LOCATION_CODE	IS_ACTIVE	CREATED_BY	CREATION_DATE
# 1	MUMBAI	MUMBAI	1	flologic1	2021-06-20 00:00:00
# 2	DELHI	DELHI	1	flologic1	2021-06-20 00:00:00
# 3	BANGALORE	BANGALORE	1	flologic1	2021-06-20 00:00:00
# */
#
#
# CREATE TABLE [M_NATURE_OF_EXPENSE] (
# 	[PK_EXPENSE_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[PURCH_ORG] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NATURE_OF_EXPENSE] NVARCHAR(150) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATED_DATE] DATETIME NULL,
# 	CONSTRAINT [PK_M_NATURE_OF_EXPENSE1] PRIMARY KEY ([PK_EXPENSE_ID])
# )
#
# /*
# 3 rows from M_NATURE_OF_EXPENSE table:
# PK_EXPENSE_ID	PURCH_ORG	NATURE_OF_EXPENSE	IS_ACTIVE	CREATED_BY	CREATED_DATE
# 1	COMMISSION	COMMISSION - SAP PARTNER	1	flologic1	2021-06-20 00:00:00
# 2	COMMISSION	COMMISSION - DISTRIBUTOR	1	flologic1	2021-06-20 00:00:00
# 3	COMMISSION	COMMISSION - FTTH	1	flologic1	2021-06-20 00:00:00
# */
#
#
# CREATE TABLE [M_PRIODICITY_OF_EXP] (
# 	[PK_PRIODICITYEXP_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[PRIODICITY_OF_EXP_NAME] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATION_DATE] DATETIME NULL
# )
#
# /*
# 3 rows from M_PRIODICITY_OF_EXP table:
# PK_PRIODICITYEXP_ID	PRIODICITY_OF_EXP_NAME	IS_ACTIVE	CREATED_BY	CREATION_DATE
# 1	Annually	1	flologic1	2023-11-03 00:00:00
# 2	Half Yearly	1	flologic1	2023-11-03 00:00:00
# 3	Quarterly	1	flologic1	2023-11-03 00:00:00
# */
#
#
# CREATE TABLE [M_PROJECT_PURCHORG] (
# 	[PK_PROJECT_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[PROJECT_NAME] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PURCH_ORG] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATED_DATE] DATETIME NULL,
# 	CONSTRAINT [PK_M_PROJECT_PURCHORG] PRIMARY KEY ([PK_PROJECT_ID])
# )
#
# /*
# 3 rows from M_PROJECT_PURCHORG table:
# PK_PROJECT_ID	PROJECT_NAME	PURCH_ORG	IS_ACTIVE	CREATED_BY	CREATED_DATE
# 1	COMMISSION	COMMISSION	1	flologic1	2021-06-20 00:00:00
# 2	DFW	DFW	1	flologic1	2021-06-20 00:00:00
# 3	FACEBOOK	FACEBOOK	1	flologic1	2021-06-20 00:00:00
# */
#
#
# CREATE TABLE [M_REJECTION_REASON] (
# 	[PK_REJECTION_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[REJECTION_REASON] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATED_DATE] DATETIME NULL,
# 	[FK_CLIENTID] INTEGER NULL,
# 	CONSTRAINT [PK_M_REJECTION_REASON] PRIMARY KEY ([PK_REJECTION_ID])
# )
#
# /*
# 3 rows from M_REJECTION_REASON table:
# PK_REJECTION_ID	REJECTION_REASON	IS_ACTIVE	CREATED_BY	CREATED_DATE	FK_CLIENTID
#
# */
#
#
# CREATE TABLE [M_SAP_FIN_DTL] (
# 	[PK_SAP_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[VENDOR_DOC_NO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[BTS_NO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATION_DATE] DATETIME NULL,
# 	[OILFLAG] INTEGER NULL,
# 	CONSTRAINT [PK_M_SAP_FIN_DTL] PRIMARY KEY ([PK_SAP_ID])
# )
#
# /*
# 3 rows from M_SAP_FIN_DTL table:
# PK_SAP_ID	VENDOR_DOC_NO	BTS_NO	CREATED_BY	CREATION_DATE	OILFLAG
#
# */
#
#
# CREATE TABLE [M_TAX_CODE] (
# 	[PK_TAXCODE_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[CI] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PROC] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TX] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TYP] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DESCRIPTION] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATION_DATE] DATETIME NULL,
# 	CONSTRAINT [PK_M_TAX_CODE] PRIMARY KEY ([PK_TAXCODE_ID])
# )
#
# /*
# 3 rows from M_TAX_CODE table:
# PK_TAXCODE_ID	CI	PROC	TX	TYP	DESCRIPTION	IS_ACTIVE	CREATED_BY	CREATION_DATE
# 1	295	TAXINN	1	V	10% Sales Tax	1	None	None
# 2	295	TAXINN	2	V	15 % Sales Tax	1	None	None
# 3	295	TAXINN	3	V	4 % CST	1	None	None
# */
#
#
# CREATE TABLE [M_TDS_TAXCODE] (
# 	[PK_TDS_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[TDS_CODE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TDS_NAME] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATION_DATE] DATETIME NULL,
# 	CONSTRAINT [PK_M_TDS_TAXCODE] PRIMARY KEY ([PK_TDS_ID])
# )
#
# /*
# 3 rows from M_TDS_TAXCODE table:
# PK_TDS_ID	TDS_CODE	TDS_NAME	IS_ACTIVE	CREATED_BY	CREATION_DATE
# 1	1C	GIL -Sec 194C 2%  Contract (Inv) CO	1	None	None
# 2	1E	ZFSec 194C-Advertisemnt Inv S&H Edu Cess	1	None	None
# 3	1H	GIL - 194H 10% Commission  (Inv) CO	1	None	None
# */
#
#
# CREATE TABLE [M_UNIQUENUMBER] (
# 	[PK_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[FINANCIAL_YEAR] NVARCHAR(20) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MONTH] NVARCHAR(20) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[OBJECT_COUNT] INTEGER NULL,
# 	[OBJECTTYPE] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	CONSTRAINT [PK_M_UNIQUENUMBER] PRIMARY KEY ([PK_ID])
# )
#
# /*
# 3 rows from M_UNIQUENUMBER table:
# PK_ID	FINANCIAL_YEAR	MONTH	OBJECT_COUNT	OBJECTTYPE
# 4	20-21	AUG	663	BTS
# 5	21-22	APR	6096	BTS
# 6	22-23	DEC	8518	BTS
# */
#
#
# CREATE TABLE [M_USER] (
# 	[PK_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[AD_ID] NVARCHAR(200) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PASSWORD] NVARCHAR(200) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	CONSTRAINT [PK_M_USER] PRIMARY KEY ([PK_ID])
# )
#
# /*
# 3 rows from M_USER table:
# PK_ID	AD_ID	PASSWORD	IS_ACTIVE
#
# */
#
#
# CREATE TABLE [M_VENDOR] (
# 	[PK_VENDOR_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[VENDOR_CODE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[VENDOR_NAME] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	CONSTRAINT [PK_M_VENDOR] PRIMARY KEY ([PK_VENDOR_ID])
# )
#
# /*
# 3 rows from M_VENDOR table:
# PK_VENDOR_ID	VENDOR_CODE	VENDOR_NAME	IS_ACTIVE
# 2	302592	Campaigns	1
# 3	401947	Kshetra Unlimited	1
# 4	101697	Orient Fire Curtains India  	1
# */
#
#
# CREATE TABLE [TEMP_INVOICE_HDR1] (
# 	[PENDINGWITH] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL
# )
#
# /*
# 3 rows from TEMP_INVOICE_HDR1 table:
# PENDINGWITH
#
# */
#
#
# CREATE TABLE [TEMP_INVOICE_HDR] (
# 	[PK_INVOICE_HDR_ID] INTEGER NULL,
# 	[FK_PROCESS_ID] INTEGER NULL,
# 	[FK_INSTANCE_ID] INTEGER NULL,
# 	[REQUEST_NO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SUBMITED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SUBMITED_DATE] DATETIME NULL,
# 	[VENDOR_CODE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[VENDOR_NAME] NVARCHAR(200) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[INVOICE_TYPE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PO_TYPE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[ORDER_NO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[INVOICE_NO] NVARCHAR(max) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[INVOICE_DATE] DATETIME NULL,
# 	[INVOICE_VALUE] NUMERIC(18, 2) NULL,
# 	[FK_DEPARTMENT_ID] INTEGER NULL,
# 	[DEPARTMENT_NAME] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PURCH_ORG] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PROJECT_NAME] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[RECEP_LOCATION] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NATURE_OF_EXPENSE] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[HARD_COPY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[REMARK] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[STATUS] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMP_NAME] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAILID] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NEXT_APPR_SEQ] INTEGER NULL,
# 	[SES_NO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[POSTING_DATE] DATETIME NULL,
# 	[MIRO_DOC_NO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MIRO_ACC_DOC_NO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PAYMENT_DOC_NO] NVARCHAR(200) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PAYMENT_STATUS] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MSME_VENDOR] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DUE_DATE] DATETIME NULL,
# 	[PAID_AMOUNT] NUMERIC(18, 2) NULL,
# 	[PENDINGWITH] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MRF_NO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[LOCATION_NAME] NCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[UTR_NO] NVARCHAR(300) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SOURCE_TYPE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL
# )
#
# /*
# 3 rows from TEMP_INVOICE_HDR table:
# PK_INVOICE_HDR_ID	FK_PROCESS_ID	FK_INSTANCE_ID	REQUEST_NO	SUBMITED_BY	SUBMITED_DATE	VENDOR_CODE	VENDOR_NAME	INVOICE_TYPE	PO_TYPE	ORDER_NO	INVOICE_NO	INVOICE_DATE	INVOICE_VALUE	FK_DEPARTMENT_ID	DEPARTMENT_NAME	PURCH_ORG	PROJECT_NAME	RECEP_LOCATION	NATURE_OF_EXPENSE	HARD_COPY	REMARK	STATUS	EMP_NAME	EMAILID	NEXT_APPR_SEQ	SES_NO	POSTING_DATE	MIRO_DOC_NO	MIRO_ACC_DOC_NO	PAYMENT_DOC_NO	PAYMENT_STATUS	MSME_VENDOR	DUE_DATE	PAID_AMOUNT	PENDINGWITH	MRF_NO	LOCATION_NAME	UTR_NO	SOURCE_TYPE
# 88175	3	36007	BTS-FY-24-25-8761	cob_midcho	2025-03-31 11:39:43.060000	AHM4200209	Bharti Airtel Limited	PO	Service	2001527870	HT2519I001697840	2024-12-09 00:00:00	15930.79	1059	CELERITYX	CELERITYX-ENTERPRISE	CELERITYX-ENTERPRISE		Bandwidth Charges	No	Mail Approval already attached	Inprogress	COB Team MIDC	cob@nxtdigital.in	2	None	None	None	None	None	None	No	2025-04-10 00:00:00	None	M Venkataraman			MUMBAI                                                                                              	None	RPA
# */
#
#
# CREATE TABLE [T_ADVANCE_HDR] (
# 	[PK_ADVANCE_HRD_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[FK_VENDOR_ID] INTEGER NULL,
# 	[FK_DEPARTMENT_ID] INTEGER NULL,
# 	[FK_LOCATION_ID] INTEGER NULL,
# 	[FK_NATURE_OF_EXPENCE_ID] INTEGER NULL,
# 	[NATURE_OF_EXPENSE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PO_NO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PO_AMOUNT] NUMERIC(18, 2) NULL,
# 	[ADVANCE_AMOUNT] NUMERIC(18, 2) NULL,
# 	[BASIS_FOR_ADVANCE] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[INVOICE_SUBMISSION_DATE] DATETIME NULL,
# 	[REMARK] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[UPDATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[UPDATED_DATE] DATETIME NULL,
# 	[FK_PROCESS_ID] INTEGER NULL,
# 	[FK_INSTANCE_ID] INTEGER NULL,
# 	[REQUEST_NO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[STATUS] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PAYMENT_DOC_NO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PAYMENT_DATE] DATETIME NULL,
# 	[PAYMENT_STATUS] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PAID_AMOUNT] NUMERIC(18, 2) NULL,
# 	[PAYMENT_UTR_NO] NVARCHAR(1000) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[VENDOR_NAME] NVARCHAR(200) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[INVC_TYPE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[VENDOR_CODE] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	CONSTRAINT [PK_T_ADVANCE_HDR] PRIMARY KEY ([PK_ADVANCE_HRD_ID])
# )
#
# /*
# 3 rows from T_ADVANCE_HDR table:
# PK_ADVANCE_HRD_ID	FK_VENDOR_ID	FK_DEPARTMENT_ID	FK_LOCATION_ID	FK_NATURE_OF_EXPENCE_ID	NATURE_OF_EXPENSE	PO_NO	PO_AMOUNT	ADVANCE_AMOUNT	BASIS_FOR_ADVANCE	INVOICE_SUBMISSION_DATE	REMARK	UPDATED_BY	UPDATED_DATE	FK_PROCESS_ID	FK_INSTANCE_ID	REQUEST_NO	STATUS	PAYMENT_DOC_NO	PAYMENT_DATE	PAYMENT_STATUS	PAID_AMOUNT	PAYMENT_UTR_NO	VENDOR_NAME	INVC_TYPE	VENDOR_CODE
# 1	None	1	1	63	None	12345	12000.00	1200.00	testing	2024-12-23 00:00:00	testing	flologic1	2024-12-23 18:50:00.230000	4	1	AR-FY-24-25-1	Rejected	12	2024-12-23 00:00:00	Partial	1000.00	123	Flologic Automation Pvt. Ltd.	PO	None
# 2	None	1	1	63	None		0.00	11000.00	testing NON PO	2024-12-23 00:00:00	test	flologic1	2024-12-23 19:09:09.113000	4	2	AR-FY-24-25-2	Rejected	123	2024-12-23 00:00:00	Partial	2000.00	321	Flologic Automation Pvt. Ltd.	Non PO	None
# 3	None	49	4	40	None		0.00	5000.00	testing	2024-12-23 00:00:00	testing	flologic1	2024-12-23 19:25:41.707000	4	3	AR-FY-24-25-3	Pending With Authority Person	None	None	None	None	None	Adfactors Pr Private Limited	Non PO	None
# */
#
#
# CREATE TABLE [T_INVOICE_PAYMET_DTL] (
# 	[PK_INVOICE_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[FK_INVOICE_ID] INTEGER NULL,
# 	[SES_NO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PAYMENT_DATE] DATETIME NULL,
# 	[MIRO_DOC_NO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MIRO_ACC_DOC_NO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FI_PAYMENT_DOC_NO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[UTR_NO] NVARCHAR(300) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PAYMENT_STATUS] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PAID_AMOUNT] NUMERIC(18, 2) NULL,
# 	[REMARK] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	CONSTRAINT [PK_T_INVOICE_PAYMET_DTL] PRIMARY KEY ([PK_INVOICE_ID])
# )
#
# /*
# 3 rows from T_INVOICE_PAYMET_DTL table:
# PK_INVOICE_ID	FK_INVOICE_ID	SES_NO	PAYMENT_DATE	MIRO_DOC_NO	MIRO_ACC_DOC_NO	FI_PAYMENT_DOC_NO	UTR_NO	PAYMENT_STATUS	PAID_AMOUNT	REMARK
# 8	68484	None	2024-07-26 00:00:00	3015156	3015156	6001399	YESIG42080117537	Fully	0.00	PAID
# 10	68485	None	2024-07-30 00:00:00	1900195348 	1900195348 		Only For Booking	Fully	0.00	Only For Booking
# 12	68464	None	2024-07-30 00:00:00	1900195338 	1900195338 		Only For Booking	Fully	0.00	Only For Booking
# */
#
#
# CREATE TABLE [T_INVOICE_SUBMISSION_DTL] (
# 	[PK_INVOICE_DTL_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[FK_HDR_ID] INTEGER NULL,
# 	[FK_GL_CODE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DESCRIPTION] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PROFIT_CENTRE] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FK_COST_CENTRE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[ASSIGNMENT] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[BASIC_AMOUNT] DECIMAL(18, 2) NULL,
# 	[TEXT_NARATION] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FK_BUSINESS_PLACE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[ACTION_NAME] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FK_TAX_CODE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[HSN_NO] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FK_TDS] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NET_AMOUNT] DECIMAL(18, 2) NULL,
# 	CONSTRAINT [PK_T_INVOICE_SUBMISSION_DTL] PRIMARY KEY ([PK_INVOICE_DTL_ID])
# )
#
# /*
# 3 rows from T_INVOICE_SUBMISSION_DTL table:
# PK_INVOICE_DTL_ID	FK_HDR_ID	FK_GL_CODE	DESCRIPTION	PROFIT_CENTRE	FK_COST_CENTRE	ASSIGNMENT	BASIC_AMOUNT	TEXT_NARATION	FK_BUSINESS_PLACE	ACTION_NAME	FK_TAX_CODE	HSN_NO	FK_TDS	NET_AMOUNT
#
# */
#
#
# CREATE TABLE [T_INVOICE_SUBMISSION_HDR] (
# 	[PK_INVOICE_HDR_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[INVOICE_TYPE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[VENDOR_NAME] NVARCHAR(200) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PO_TYPE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[ORDER_NO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[INVOICE_NO] NVARCHAR(max) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[INVOICE_DATE] DATETIME NULL,
# 	[INVOICE_VALUE] NUMERIC(18, 2) NULL,
# 	[FK_DEPARTMENT_ID] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PROJECT_NAME] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[RECEP_LOCATION] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NATURE_OF_EXPENSE] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[REMARK] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[VENDOR_CODE] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[HARD_COPY] NCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SUBMITED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SUBMITED_DATE] DATETIME NULL,
# 	[STATUS] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FK_PROCESS_ID] INTEGER NULL,
# 	[FK_INSTANCE_ID] INTEGER NULL,
# 	[REQUEST_NO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FK_REJECTION_ID] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NEXT_APPR_SEQ] INTEGER NULL,
# 	[SES_NO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[POSTING_DATE] DATETIME NULL,
# 	[MIRO_DOC_NO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MIRO_ACC_DOC_NO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PAYMENT_DOC_NO] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PAYMENT_STATUS] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MSME_VENDOR] NCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[UPDATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[UPDATED_DATE] DATETIME NULL,
# 	[DUE_DATE] DATETIME NULL,
# 	[PAID_AMOUNT] NUMERIC(18, 2) NULL,
# 	[MRF_NO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FK_BRANCH_ID] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SRN_NO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[UTR_NO] NVARCHAR(300) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[GST] NCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FK_PRIODICITYEXP_ID] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EXPRENSE_TYPE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[COMPANY_NAME] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[BASIC_AMOUNT] NUMERIC(18, 2) NULL,
# 	[SGST_AMOUNT] NUMERIC(18, 2) NULL,
# 	[CGST_AMOUNT] NUMERIC(18, 2) NULL,
# 	[IGST_AMOUNT] NUMERIC(18, 2) NULL,
# 	[COMPANY_GST_NO] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[GST_NO] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PO_DATE] DATETIME NULL,
# 	[BALANCE_AMOUNT] NUMERIC(18, 2) NULL,
# 	[SOURCE_TYPE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[INV_BOOK_TYPE] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[JSONFORMAT] NVARCHAR(max) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SAP_RESULT] SMALLDATETIME NULL,
# 	[INVOICE_PERIOD_START_DATE] DATETIME NULL,
# 	[INVOICE_PERIOD_END_DATE] DATETIME NULL,
# 	[SAP_VENDOR_DOC_DATA] NVARCHAR(max) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[APP_FLAG] NCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[INVC_AGAINST_ADVANCE] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[OTHER_REF_NO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	CONSTRAINT [PK_T_INVOICE_SUBMISSION_HDR] PRIMARY KEY ([PK_INVOICE_HDR_ID])
# )
#
# /*
# 3 rows from T_INVOICE_SUBMISSION_HDR table:
# PK_INVOICE_HDR_ID	INVOICE_TYPE	VENDOR_NAME	PO_TYPE	ORDER_NO	INVOICE_NO	INVOICE_DATE	INVOICE_VALUE	FK_DEPARTMENT_ID	PROJECT_NAME	RECEP_LOCATION	NATURE_OF_EXPENSE	REMARK	VENDOR_CODE	HARD_COPY	SUBMITED_BY	SUBMITED_DATE	STATUS	FK_PROCESS_ID	FK_INSTANCE_ID	REQUEST_NO	FK_REJECTION_ID	NEXT_APPR_SEQ	SES_NO	POSTING_DATE	MIRO_DOC_NO	MIRO_ACC_DOC_NO	PAYMENT_DOC_NO	PAYMENT_STATUS	MSME_VENDOR	UPDATED_BY	UPDATED_DATE	DUE_DATE	PAID_AMOUNT	MRF_NO	FK_BRANCH_ID	SRN_NO	UTR_NO	GST	FK_PRIODICITYEXP_ID	EXPRENSE_TYPE	COMPANY_NAME	BASIC_AMOUNT	SGST_AMOUNT	CGST_AMOUNT	IGST_AMOUNT	COMPANY_GST_NO	GST_NO	PO_DATE	BALANCE_AMOUNT	SOURCE_TYPE	INV_BOOK_TYPE	JSONFORMAT	SAP_RESULT	INVOICE_PERIOD_START_DATE	INVOICE_PERIOD_END_DATE	SAP_VENDOR_DOC_DATA	APP_FLAG	INVC_AGAINST_ADVANCE	OTHER_REF_NO
# 1	PO	VIDEO SPECTRUM	Service	5100000952	VS-01	2020-09-17 00:00:00	32809.00	19	DFW	Delhi	Fiber  Lease 	PO realeased by Siddhesh	DEL4200272 	No        	BTS443	2020-09-21 15:52:44.750000	Completed	3	1	BTS-FY-20-21-1	None	3	None	None	5105618497	5105618497	1800000870	Fully	No        	None	None	2020-10-16 00:00:00	32561.72	None	2	None	None	No        	None	None	None	None	None	None	None	None	None	None	None	RPA	None	None	None	None	None	None	None	None	None
# 2	PO	B P CABLE 	Service	5100000918	BP-01	2020-09-23 00:00:00	15451.00	19	DFW	Delhi	Fiber  Lease 	MRF/2020-2021/1655	DEL4100214	No        	BTS443	2020-09-26 11:18:24.393000	Completed	3	2	BTS-FY-20-21-2	None	3	None	2020-10-23 00:00:00	5100000918	5100000918	1800000995	Fully	No        	None	None	2020-10-22 00:00:00	15335.08	MRF/2020-2021/1655	2	None	None	No        	None	None	None	None	None	None	None	None	None	None	None	RPA	None	None	None	None	None	None	None	None	None
# 3	PO	CLASSIC CABLE	Service	5100001023	3	2020-10-04 00:00:00	127182.87	19	DFW	Delhi	Fiber  Lease 	MRF/2020-2021/1785
# 	DEL4200288	No        	BTS440	2020-10-04 17:52:16.870000	Completed	3	3	BTS-FY-20-21-3	None	3	None	None	5105618584	5105618584	1800000973	Fully	No        	None	None	2020-10-10 00:00:00	126227.99	MRF/2020-2021/1785	2	None	None	No        	None	None	None	None	None	None	None	None	None	None	None	RPA	None	None	None	None	None	None	None	None	None
# */
#
#
# CREATE TABLE [T_INVOICE_SUBMISSION_PODTL] (
# 	[PK_PODTL_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[BTS_NO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MANDT] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PO_NO] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PO_ITEM] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DOC_DATE] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PO_VALUE] NUMERIC(18, 2) NULL,
# 	[VENDOR] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MATERIAL] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PO_QUANTITY] INTEGER NULL,
# 	[TAX_CODE] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PAYMENT_TERMS] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MOVE_TYPE] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MAT_DOC] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[POSTING_DATE] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[QUANTITY] INTEGER NULL,
# 	[PO_START_DATE] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PO_END_DATE] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[UNIT_PRICE] NUMERIC(18, 2) NULL,
# 	CONSTRAINT [PK_T_INVOICE_SUBMISSION_PODTL] PRIMARY KEY ([PK_PODTL_ID])
# )
#
# /*
# 3 rows from T_INVOICE_SUBMISSION_PODTL table:
# PK_PODTL_ID	BTS_NO	MANDT	PO_NO	PO_ITEM	DOC_DATE	PO_VALUE	VENDOR	MATERIAL	PO_QUANTITY	TAX_CODE	PAYMENT_TERMS	MOVE_TYPE	MAT_DOC	POSTING_DATE	QUANTITY	PO_START_DATE	PO_END_DATE	UNIT_PRICE
#
# */
#
#
# CREATE TABLE [T_LOGIN] (
# 	[PK_LOGIN_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[LOGINID] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[LOGINTIME] DATETIME NULL,
# 	[LOGOUTTIME] DATETIME NULL,
# 	[TOKENID] NVARCHAR(max) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DOMAIN] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[APP_SESSID] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FORCELOGPUTFLAG] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DOMAINHOSTNAME] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	CONSTRAINT [PK_T_LOGIN] PRIMARY KEY ([PK_LOGIN_ID])
# )
#
# /*
# 3 rows from T_LOGIN table:
# PK_LOGIN_ID	LOGINID	LOGINTIME	LOGOUTTIME	TOKENID	DOMAIN	APP_SESSID	FORCELOGPUTFLAG	DOMAINHOSTNAME
# 1	flologic1	2020-08-13 15:43:19.267000	None		BTS	h3se40iy5jbypz24izpe0a2v	None	DESKTOP-TOMFRLP
# 2	flologic1	2020-08-13 15:47:01.300000	None		BTS	hb0rgb3mbr543tp2kl3bhmle	None	DESKTOP-TOMFRLP
# 3	flologic1	2020-08-13 15:49:01.987000	None		BTS	hb0rgb3mbr543tp2kl3bhmle	None	DESKTOP-TOMFRLP
# */
#
#
# CREATE TABLE [T_MAILLOG] (
# 	[PK_MAIL_ID] INTEGER NOT NULL IDENTITY(1,1),
# 	[FK_PROCESSID] INTEGER NULL,
# 	[FK_INSTANCEID] INTEGER NULL,
# 	[FK_WIID] INTEGER NULL,
# 	[STEP_NAME] VARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[ACTION] VARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TO_MAIL] NVARCHAR(200) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CC_MAIL] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MAIL_BODY] NVARCHAR(max) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MAILSENT_FLAG] BIT NULL,
# 	[CREATION_DATE] DATETIME NULL,
# 	[SENT_DATE] DATETIME NULL,
# 	[HEADER] VARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SENDINGFAIL_FLAG] BIT NULL,
# 	[ERROR_MSG] NVARCHAR(max) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	CONSTRAINT [PK_T_HD_MAILLOG] PRIMARY KEY ([PK_MAIL_ID])
# )
#
# /*
# 3 rows from T_MAILLOG table:
# PK_MAIL_ID	FK_PROCESSID	FK_INSTANCEID	FK_WIID	STEP_NAME	ACTION	TO_MAIL	CC_MAIL	MAIL_BODY	MAILSENT_FLAG	CREATION_DATE	SENT_DATE	HEADER	SENDINGFAIL_FLAG	ERROR_MSG
# 1	3	41	1	INVOICE APPROVAL	SUBMIT	sanjeev.chopra@onebroadband.in		<html><body><h4 style='margin: 20px 0px 0px; font-family: Karla, sans-serif; background-color: rgb(2	False	2020-08-13 18:15:04.083000	2020-09-17 15:08:00.480000	Invoice Approval	None	None
# 2	3	42	2	INVOICE APPROVAL	SUBMIT	sanjeev.chopra@onebroadband.in		<html><body><h4 style='margin: 20px 0px 0px; font-family: Karla, sans-serif; background-color: rgb(2	False	2020-08-13 18:17:00.767000	2020-09-17 15:08:00.497000	Invoice Approval	None	None
# 3	3	41	3	INVOICE APPROVAL	APPROVE	sanjay.singh@onebroadband.in		<html><body><h4 style='margin: 20px 0px 0px; font-family: Karla, sans-serif; background-color: rgb(2	False	2020-08-13 18:26:46.163000	2020-09-17 15:08:00.497000	Invoice Approval	None	None
# */
#
#
# CREATE TABLE [T_UPLOADINVOICE_MODIFICATIONDATA_HDR_ORG] (
# 	[PK_HDR_ID] BIGINT NOT NULL IDENTITY(1,1),
# 	[VENDOR_NAME] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PO_NO] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PO_DATE] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[INVOICE_NOTE_NO] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[INVOICE_DATE] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[INVC_BOOK_TYPE] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[REF_INVOICE_NO] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[REF_INVOICE_DATE] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[BASIC_AMOUNT] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IGST_AMOUNT] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CGST_AMOUNT] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SGST_AMOUNT] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PAYMENT_DUE_DATE] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[LOCATION] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[COMPANY_NAME] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[GST_NO] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[COMPANY_GST_NO] NVARCHAR(250) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[STATUS] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DOC_PATH] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[USER_ID] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATED_BY] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CREATED_AT] DATETIME NULL,
# 	[IS_ACTIVE] INTEGER NULL,
# 	[CONFIDENCE_FLAG] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	CONSTRAINT [PK_T_UPLOADINVOICE_FOR_MODIFICATIONDATA_HDR_ORG] PRIMARY KEY ([PK_HDR_ID])
# )
#
# /*
# 3 rows from T_UPLOADINVOICE_MODIFICATIONDATA_HDR_ORG table:
# PK_HDR_ID	VENDOR_NAME	PO_NO	PO_DATE	INVOICE_NOTE_NO	INVOICE_DATE	INVC_BOOK_TYPE	REF_INVOICE_NO	REF_INVOICE_DATE	BASIC_AMOUNT	IGST_AMOUNT	CGST_AMOUNT	SGST_AMOUNT	PAYMENT_DUE_DATE	LOCATION	COMPANY_NAME	GST_NO	COMPANY_GST_NO	STATUS	DOC_PATH	USER_ID	CREATED_BY	CREATED_AT	IS_ACTIVE	CONFIDENCE_FLAG
# 1	Revmax Telecom Infrastructures Pvt.Ltd	4500018351	3-Aug-23	RTI/23-24/MH/269	2023-09-01	None	None	None	None	None	1,068.03	1,068.03	None	None	HINDUJA GLOBAL SOLUTIONS LIMITED	27AADCR5059A1ZL.	27AAACT1763A1ZR	NotStarted	C:\Flologic\NDL ONEOTT\Production\Data\UploadDocument\flologic1\RTI-23-24-MH-269 Hinduja_UserName_fl	flologic1	flologic1	2023-12-28 17:59:36.527000	1	None
# 2	HARILAL ENTERPRISES	5100003376	8-Nov-2023	HE/23-24/216	2023-12-12	None	None	None	None	None	4,725.00	4,725.00	None	None	ONEOTT Intertainment Limited	27AETPY0650H1ZY	27AADCP6815A2ZO	NotStarted	C:\Flologic\NDL ONEOTT\Production\Data\UploadDocument\flologic1\HE-2324-216 - One OTT (1)_UserName_f	flologic1	flologic1	2023-12-29 10:11:20.620000	1	None
# 3	Hinduja Global Solutions Limited	None	None	DR5272027289	2023-12-30	None	None	None	6,600.00	None	594.00	594.00	None	None	ONEOTT Intertainment Ltd.	27AAACT1763A2ZQ	27AADCP6815A3ZN	NotStarted	C:\Flologic\NDL ONEOTT\Production\Data\UploadDocument\BTS517\ONEOTT Intertainment Ltd._DR5272027289_	BTS517	BTS517	2024-01-02 17:27:19.740000	1	None
# */

# %%
#Import Keys

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = os.getenv("LANGCHAIN_TRACING_V2")
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")

# %%
# Function to clean SQL Query generated by OpenAI LLM by removing extr chars

import re

def clean_sql_query(text: str) -> str:
    """
    Clean SQL query by removing code block syntax, various SQL tags, backticks,
    prefixes, and unnecessary whitespace while preserving the core SQL query.

    Args:
        text (str): Raw SQL query text that may contain code blocks, tags, and backticks

    Returns:
        str: Cleaned SQL query
    """
    # Step 1: Remove code block syntax and any SQL-related tags
    # This handles variations like ```sql, ```SQL, ```SQLQuery, etc.
    block_pattern = r"```(?:sql|SQL|SQLQuery|mysql|postgresql)?\s*(.*?)\s*```"
    text = re.sub(block_pattern, r"\1", text, flags=re.DOTALL)

    # Step 2: Handle "SQLQuery:" prefix and similar variations
    # This will match patterns like "SQLQuery:", "SQL Query:", "MySQL:", etc.
    prefix_pattern = r"^(?:SQL\s*Query|SQLQuery|MySQL|PostgreSQL|SQL)\s*:\s*"
    text = re.sub(prefix_pattern, "", text, flags=re.IGNORECASE)

    # Step 3: Extract the first SQL statement if there's random text after it
    # Look for a complete SQL statement ending with semicolon
    sql_statement_pattern = r"(SELECT.*?;)"
    sql_match = re.search(sql_statement_pattern, text, flags=re.IGNORECASE | re.DOTALL)
    if sql_match:
        text = sql_match.group(1)

    # Step 4: Remove backticks around identifiers
    text = re.sub(r'`([^`]*)`', r'\1', text)

    # Step 5: Normalize whitespace
    # Replace multiple spaces with single space
    text = re.sub(r'\s+', ' ', text)

    # Step 6: Preserve newlines for main SQL keywords to maintain readability
    keywords = ['SELECT', 'FROM', 'WHERE', 'GROUP BY', 'HAVING', 'ORDER BY',
               'LIMIT', 'JOIN', 'LEFT JOIN', 'RIGHT JOIN', 'INNER JOIN',
               'OUTER JOIN', 'UNION', 'VALUES', 'INSERT', 'UPDATE', 'DELETE']

    # Case-insensitive replacement for keywords
    pattern = '|'.join(r'\b{}\b'.format(k) for k in keywords)
    text = re.sub(f'({pattern})', r'\n\1', text, flags=re.IGNORECASE)

    # Step 7: Final cleanup
    # Remove leading/trailing whitespace and extra newlines
    text = text.strip()
    text = re.sub(r'\n\s*\n', '\n', text)

    # Step 8: 
    if text.startswith("`sql SQLQuery:"):
        text = text[len("`sql SQLQuery:"):].lstrip()

    return text

# %%
# Generate Query using DB info 

from langchain.chains import create_sql_query_chain
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model=os.getenv("OPENAI_MODEL"), temperature=0)
generate_query = create_sql_query_chain(llm, db)

query = generate_query.invoke({"question": "list all unique vendors present"})
print(query)
# Out:
# ```sql
# SQLQuery: SELECT DISTINCT [VENDOR_NAME] FROM [T_INVOICE_SUBMISSION_HDR] WHERE [VENDOR_NAME] IS NOT NULL

# %%
# Call Function to clean SQL Query generated by OpenAI LLM to removing extr chars so that we can execute without syntax error

print("-"*150)
query = clean_sql_query(query)
print(query)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# SELECT DISTINCT [VENDOR_NAME]
# FROM [T_INVOICE_SUBMISSION_HDR]
# WHERE [VENDOR_NAME] IS NOT NULL

# %%
# Execute Query 

from langchain_community.tools.sql_database.tool import QuerySQLDataBaseTool

execute_query = QuerySQLDataBaseTool(db=db)
execute_query.invoke(query)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7588\4206419260.py:5: LangChainDeprecationWarning: The class `QuerySQLDataBaseTool` was deprecated in LangChain 0.3.12 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-community package and should be used instead. To use it run `pip install -U :class:`~langchain-community` and import as `from :class:`~langchain_community.tools import QuerySQLDatabaseTool``.
#   execute_query = QuerySQLDataBaseTool(db=db)
# '[(\'Sadguru Broadband Service\',), (\'BSB ELECTRONICS\',), (\'SWITCHING_CHANNELS\',), (\'Dhruva Advisors LLP\',), (\'Star Link Cable Network\',), (\'RAHUL AGARWAL \',), (\'MARK CERTIFICATION CONSULTANTS\',), (\'Aarushi Gupta /sanjayg_kn            \',), (\'Rajasthan Cable Network Service Sunel /5012968\',), (\'5013307_Fypoint_Coco_Eaeg_Shreeenterprises_New\',), (\'Sushil Sundaram/ss_sushils\',), (\'GUPTA PRINTERS\',), (\'S. K. CONSULTANTS/ss_santoshikamble\',), (\'sumitb_ws / Rutuja Pradip Ambekar\',), (\'Fibra Netway Private Limited\',), (\'Umesh Cable Network\',), (\'5001768_Ftth_Coco_W1_Wc12_Navsonarbala\',), (\'5015805 - Coco_Honesty Telecom - Bhandup Maharashtra Nagar\',), (\'RADHEY CABLE NETWORK\',), (\'Sway Computer\',), (\'Jayram J Palav\',), (\'Ajinkya Modak/ss_ajinkya09\',), (\'Ram_Cable NEtwork_Delhi\',), (\'Virendra Gunvantrai Bhatt\',), (\'SSV Broadband Pvt.Ltd.\',), (\'ABC/TEST\',), (\'SHIVA SAI CABLE NETWORK\',), (\'5000061_Delhi-Sargam_Cable\',), ("Prashant James D\'souza",), (\'S-WAY COMPUTER\',), (\'Shakti Enterprise\',), (\'Rcn Fibernet_Ors204798\',), (\'Sandeep optical Infra\',), (\'Alden Rebello\',), (\'Raxxmo  Network Pvt Ltd\',), (\'Kolhapur_Siddhivinayak_Cable_KOLH\\xa0\',), (\'Shree Tisai Cable Services Pvt Ltd\',), (\'Fiberx Networks Private Limited\',), (\'Angel Air Network Solutions Private Limited\',), (\'Blue Star Limited\',), (\'ADANI ELECTRICITY\',), (\'IN ENTERTAINMENT (I) LTD\',), (\'YM MOTORS PVT LTD\',), (\'GOLD FINCH HOTEL\',), (\'5003878_BMISPL_Mamta_Management\',), (\'ARKABIZ TECHNOLOGIES PRIVATE LTD\',), (\'Coco_Chaudhary_115\',), (\'Saini Enterprises 5011230\',), (\'ss_kishormane\',), (\'CENTURY ESTATES\',), (\'SPACEHITZ_NPL/5013192\',), (\'GIGANET TECHNOLOGIES /5002112\\t\',), (\'Syntego Technologies India Private\',), (\'Fibernet Internet Service Provider\',), (\'Ors204752_Galaxynet Connections Private Limited\',), (\'Roopa D S\\t\',), (\'Charvi_Enterprise\',), (\'Hrushikesh Govind Rayate\',), (\'Star Communication\',), (\'FAHNET TELECOM\',), (\'Gefo Fiber\',), (\'Guj4114505_Mishal Internet\\t\',), (\'Ramniranjan Kedia Rent A Car Pvt.Ltd\',), (\'NILAM ENTERPRISES\',), (\'NETLINK INTERNET SERVICE\',), (\'Akira_Agencies \\t\\t\\t\\t\',), (\'Kajal Arunkumar Pandya/ss_kajal1501\',), (\'5000087_Miraroad_Ayush_Video\',), (\'5003858_Cable wave Network 1\',), (\'Fypoint Technologies\',), (\'SIDDHIVINAYAK CABLE\',), (\'dipak_eoc /Dipak Laxmidas Porecha\',), (\'Manik Travels / sadguru_shop5\',), (\'PRAVEEN DUBEY\',), (\'5012954_Chamunda Cable Network\',), (\'ADAPT INDIA NETWORKS\',), (\'JAYAGANESH GURUKKAL\',), (\'SAMtech Enterprises\',), (\'AMN DESIGNRIDE PVT LTD\',), (\'Runtime Solutions Pvt. Ltd.\',), (\'MULTIPLIER\',), (\'Ambika Communication\',), (\'REENA VYAS / ftth_Reena404\',), (\'Vinita Singh /5011379\',), (\'hasmukh_1605 / hasmukh prajapati\',), (\'Om Shree Cable Network\',), (\'International Market Assessment India Private Limited\',), (\'MW FIBERNET\',), (\'New Era Informatique P Ld\',), (\'J K NET SOLUTIONS\',), (\'Express Digitech\',), (\'Jaisingh & Associates\',), (\'Sumit Sudhir Ghule\',), (\'CityLink Infratech Pvt. Ltd\',), (\'\\xa0Guru_Krupa_Cable_Network /5001752\',), (\'NAS Internet Services Pvt. Ltd.\',), (\'Sandip Vaman Mali\',), (\'Sri Lakshmi Venkateshwara Cable Network\',), (\'KALCON COMMUNICATION\',), (\'Ramdas Chaudhary Tempo Service\',), (\'Mum4201381_Netline Broadband Internet Service\',), (\'MJ INTERNET AND CCTV SERVICES\',), (\':BMISPL_Narayan Broadband\',), (\'Sai internet_indapur\',), (\'Ishan Netsol Private Limited\',), (\'Sap_One World Net_Har\',), (\'PRAVIN MAHADEV PATKAR\',), (\'SHRI MAHALASA\',), (\'Jimmi Cable Network\',), (\'SHYAM SPECTRA PVT LTD\',), (\'SKYNET INTERNET\',), (\'Ujwala Vinayak Bhor\',), (\'COCO_FTTH_SpeedNHex\',), (\'RZS COOPERATION\',), (\'Nettlinx  Limited\',), (\'TASA E SOLUTIONS\',), (\'REVEMAX TELECOM INFRASTRUCTURES PVT.LTD\',), (\'M/S S.G. ENTERPRISES\',), (\'\\tSPACECOM INTERNET Servicec PVT LTD\',), (\'R G Technosolutions Private ...

# %%
# Create chain -> to generate query -> to clean quert -> to execute query & get result

from langchain_core.runnables import RunnablePassthrough, RunnableLambda

chain = generate_query | RunnableLambda(clean_sql_query) | execute_query

chain.invoke({"question": "how many invoices are completed"})
# Out:
# '[(29930,)]'

# %%
#Prompt

chain.get_prompts()[0].pretty_print()
# Out:
# You are an MS SQL expert. Given an input question, first create a syntactically correct MS SQL query to run, then look at the results of the query and return the answer to the input question.
# Unless the user specifies in the question a specific number of examples to obtain, query for at most 5 results using the TOP clause as per MS SQL. You can order the results to return the most informative data in the database.
# Never query for all columns from a table. You must query only the columns that are needed to answer the question. Wrap each column name in square brackets ([]) to denote them as delimited identifiers.
# Pay attention to use only the column names you can see in the tables below. Be careful to not query for columns that do not exist. Also, pay attention to which column is in which table.
# Pay attention to use CAST(GETDATE() as date) function to get the current date, if the question involves "today".
#
# Use the following format:
#
# Question: Question here
# SQLQuery: SQL Query to run
# SQLResult: Result of the SQLQuery
# Answer: Final answer here
#
# Only use the following tables:
# {table_info}
#
# Question: {input}

# %%
# result Chain -> to generate query -> to clean quert -> to execute query & get result -> Rephrase answer using Question asked, query & Sql execution reult

from operator import itemgetter

from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough, RunnableLambda

answer_prompt = PromptTemplate.from_template(
       """Given the following user question, corresponding SQL query, and SQL result, answer the user question.

Question: {question}
SQL Query: {query}
SQL Result: {result}
Answer: """
)

rephrase_answer = answer_prompt | llm | StrOutputParser()

chain = (
    RunnablePassthrough.assign(query=generate_query | RunnableLambda(clean_sql_query)).assign(
        result=itemgetter("query") | execute_query
    )
    | rephrase_answer
)

chain.invoke({"question": "for how many companies invoices are completed"})
# Out:
# 'There are 3,214 companies for which invoices are completed.'

# %% [markdown]
# # Adding few-shot examples

# %%
# Establish a set of questions and their associated queries to serve as reference inputs for the language model.

examples = [
    {
        "input": "For how many companies have invoices been completed",
        "query": "SELECT COUNT(DISTINCT [VENDOR_NAME]) AS CompletedInvoicesCount FROM [T_INVOICE_SUBMISSION_HDR] WHERE [STATUS] = 'Completed';"
    },
    {
        "input": "What is the total number of completed invoices",
        "query": "SELECT COUNT(*) AS CompletedInvoices FROM T_INVOICE_SUBMISSION_HDR WHERE STATUS = 'Completed'"
    },
    {
        "input": "How many orders are there",
        "query": "SELECT COUNT(*) AS [TotalOrders] FROM [T_INVOICE_SUBMISSION_HDR]"
    },
    {
        "input": "list all unique vendors present",
        "query": "SQLQuery: SELECT DISTINCT [VENDOR_NAME] FROM [T_INVOICE_SUBMISSION_HDR] WHERE [VENDOR_NAME] IS NOT NULL"
    }
    
]

# %%
# Convert above example into Human statements (questions) & AI(LLM) statements (response) 

from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder,FewShotChatMessagePromptTemplate,PromptTemplate

example_prompt = ChatPromptTemplate.from_messages(
    [
        ("human", "{input}\nSQLQuery:"),
        ("ai", "{query}"),
    ]
)
few_shot_prompt = FewShotChatMessagePromptTemplate(
    example_prompt=example_prompt,
    examples=examples,
    # input_variables=["input","top_k"],
    input_variables=["input"],
)
print(few_shot_prompt.format(input1="What is the count of invoices"))
# Out:
# Human: For how many companies have invoices been completed
# SQLQuery:
# AI: SELECT COUNT(DISTINCT [VENDOR_NAME]) AS CompletedInvoicesCount FROM [T_INVOICE_SUBMISSION_HDR] WHERE [STATUS] = 'Completed';
# Human: What is the total number of completed invoices
# SQLQuery:
# AI: SELECT COUNT(*) AS CompletedInvoices FROM T_INVOICE_SUBMISSION_HDR WHERE STATUS = 'Completed'
# Human: How many orders are there
# SQLQuery:
# AI: SELECT COUNT(*) AS [TotalOrders] FROM [T_INVOICE_SUBMISSION_HDR]
# Human: list all unique vendors present
# SQLQuery:
# AI: SQLQuery: SELECT DISTINCT [VENDOR_NAME] FROM [T_INVOICE_SUBMISSION_HDR] WHERE [VENDOR_NAME] IS NOT NULL

# %% [markdown]
# # Dynamic few-shot example selection

# %%
#Using Semantic search, choose only the relavent set of examples to pass as reference  

from langchain_chroma import Chroma
from langchain_core.example_selectors import SemanticSimilarityExampleSelector
from langchain_openai import OpenAIEmbeddings

vectorstore = Chroma()
vectorstore.delete_collection()
example_selector = SemanticSimilarityExampleSelector.from_examples(
    examples,
    OpenAIEmbeddings(),
    vectorstore,
    k=2,
    input_keys=["input"],
)
example_selector.select_examples({"input": "What is the count of invoices?"})
# Out:
# [{'input': 'What is the total number of completed invoices',
#   'query': "SELECT COUNT(*) AS CompletedInvoices FROM T_INVOICE_SUBMISSION_HDR WHERE STATUS = 'Completed'"},
#  {'input': 'For how many companies have invoices been completed',
#   'query': "SELECT COUNT(DISTINCT [VENDOR_NAME]) AS CompletedInvoicesCount FROM [T_INVOICE_SUBMISSION_HDR] WHERE [STATUS] = 'Completed';"}]

# %%
# Convert relavent set of examples into Human statements (questions) & AI(LLM) statements (response) 

few_shot_prompt = FewShotChatMessagePromptTemplate(
    example_prompt=example_prompt,
    example_selector=example_selector,
    input_variables=["input","top_k"],
)
print(few_shot_prompt.format(input="What is the count of invoices?"))
# Out:
# Human: What is the total number of completed invoices
# SQLQuery:
# AI: SELECT COUNT(*) AS CompletedInvoices FROM T_INVOICE_SUBMISSION_HDR WHERE STATUS = 'Completed'
# Human: For how many companies have invoices been completed
# SQLQuery:
# AI: SELECT COUNT(DISTINCT [VENDOR_NAME]) AS CompletedInvoicesCount FROM [T_INVOICE_SUBMISSION_HDR] WHERE [STATUS] = 'Completed';

# %%
# Combine above steps with user Question

final_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a MySQL expert. Given an input question, create a syntactically correct MySQL query to run. Unless otherwise specificed.\n\nHere is the relevant table info: {table_info}\n\nBelow are a number of examples of questions and their corresponding SQL queries."),
        few_shot_prompt,
        ("human", "{input}"),
    ]
)
print(final_prompt.format(input="What is the count of invoices?",table_info="some table info"))
# Out:
# System: You are a MySQL expert. Given an input question, create a syntactically correct MySQL query to run. Unless otherwise specificed.
#
# Here is the relevant table info: some table info
#
# Below are a number of examples of questions and their corresponding SQL queries.
# Human: What is the total number of completed invoices
# SQLQuery:
# AI: SELECT COUNT(*) AS CompletedInvoices FROM T_INVOICE_SUBMISSION_HDR WHERE STATUS = 'Completed'
# Human: For how many companies have invoices been completed
# SQLQuery:
# AI: SELECT COUNT(DISTINCT [VENDOR_NAME]) AS CompletedInvoicesCount FROM [T_INVOICE_SUBMISSION_HDR] WHERE [STATUS] = 'Completed';
# Human: What is the count of invoices?

# %%
# result Chain -> to generate query with relavent set of Human question & AI response of query-> to clean query -> to execute query & get result -> Rephrase answer using Question asked, query & Sql execution reult


generate_query = create_sql_query_chain(llm, db,final_prompt)

chain = (
    RunnablePassthrough.assign(query=generate_query | RunnableLambda(clean_sql_query)).assign(
        result=itemgetter("query") | execute_query
    )
    | rephrase_answer
)

chain.invoke({"question": "What is the count of invoices?"})
# Out:
# 'The count of invoices is 36,090.'

# %% [markdown]
# # Dynamic relevant table selection

# %%
# Select the most relevant database tables and include their details to improve the accuracy of query generation by the LLM

from operator import itemgetter
#from langchain.chains.openai_tools import create_extraction_chain_pydantic
from pydantic import BaseModel, Field
from typing import List
import pandas as pd

def get_table_details():
    # Read the CSV file into a DataFrame
    table_description = pd.read_excel("TableInfo.xlsx")
    table_docs = []

    # Iterate over the DataFrame rows to create Document objects
    table_details = ""
    for index, row in table_description.iterrows():
        table_details = table_details + "Table Name:" + row['table_name'] + "\n" + "Table Description:" + row['description'] + "\n\n"

    return table_details


class Table(BaseModel):
    """Table in SQL database."""

    name: List[str] = Field(description="List of Name of tables in SQL database.")

# table_names = "\n".join(db.get_usable_table_names())
table_details = get_table_details()
print(table_details)
# Out:
# Table Name:M_DEPARTMENT
# Table Description:Holds the information of Depart ment name department description department head and creation date
#
# Table Name:T_INVOICE_SUBMISSION_HDR
# Table Description:Holds the information of Invoice type, vendor name, PO number, Invoice number, invoice date, invoice value, Foreign key of department, project name, project location

# %%
# The input consists of a table name and a short description. The output will be a list of relevant database tables based on this context

table_details_prompt = ChatPromptTemplate.from_messages(
        [
            ("system", """Return the names of ALL the SQL tables that MIGHT be relevant to the user question.
                          The tables are:

                          {table_details}

                          Remember to include ALL POTENTIALLY RELEVANT tables, even if you're not sure that they're needed."""),
            ("human", "{question}")
        ]
    )

structured_llm = llm.with_structured_output(Table)

table_chain = table_details_prompt | structured_llm
tables = table_chain.invoke({"question": "which department has submitted the highest number of invoices?", "table_details":table_details})
tables
# Out:
# Table(name=['M_DEPARTMENT', 'T_INVOICE_SUBMISSION_HDR'])

# %%
# function to defines and a processing pipeline to extract relevant database table names based on a user's question and associated table metadata.

def get_tables(table_response: Table) -> List[str]:
    """
    Extracts the list of table names from a Table object.

    Args:
        table_response (Table): A Pydantic Table object containing table names.

    Returns:
        List[str]: A list of table names.
    """
    return table_response.name

select_table = {"question": itemgetter("question"), "table_details": itemgetter("table_details")} | table_chain | get_tables

select_table.invoke({"question": "give me details of customer and their order count", "table_details":table_details})
# Out:
# ['M_DEPARTMENT', 'T_INVOICE_SUBMISSION_HDR']

# %%
# result Chain -> to generate query with (relavent set of Human question & AI response of query) & (relavent set of DB tables & its details) -> to clean query -> to execute query & get result -> Rephrase answer using Question asked, query & Sql execution reult

chain = (
RunnablePassthrough.assign(table_names_to_use=select_table) |
RunnablePassthrough.assign(query=generate_query | RunnableLambda(clean_sql_query)).assign(
    result=itemgetter("query") | execute_query
)
| rephrase_answer
)
chain.invoke({"question": "what is the total invoice count in last 3 months ?", "table_details":table_details})
# Out:
# 'The total invoice count in the last 3 months is 1,653.'

# %%
chain.invoke({"question": "what is the toatl count in last 2 months ?", "table_details":table_details})
# Out:
# 'The total count in the last 2 months is 579.'

# %% [markdown]
# # Adding memory to the chatbot so that it answers follow-up questions

# %%
# Adding Conversation history 

final_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a MySQL expert. Given an input question, create a syntactically correct MySQL query to run. Unless otherwise specificed.\n\nHere is the relevant table info: {table_info}\n\nBelow are a number of examples of questions and their corresponding SQL queries. Those examples are just for referecne and hsould be considered while answering follow up questions"),
        few_shot_prompt,
        MessagesPlaceholder(variable_name="messages"),
        ("human", "{input}"),
    ]
)
print(final_prompt.format(input="what is the total invoice count in last 3 months ?",table_info="some table info",messages=[]))
# Out:
# System: You are a MySQL expert. Given an input question, create a syntactically correct MySQL query to run. Unless otherwise specificed.
#
# Here is the relevant table info: some table info
#
# Below are a number of examples of questions and their corresponding SQL queries. Those examples are just for referecne and hsould be considered while answering follow up questions
# Human: What is the total number of completed invoices
# SQLQuery:
# AI: SELECT COUNT(*) AS CompletedInvoices FROM T_INVOICE_SUBMISSION_HDR WHERE STATUS = 'Completed'
# Human: For how many companies have invoices been completed
# SQLQuery:
# AI: SELECT COUNT(DISTINCT [VENDOR_NAME]) AS CompletedInvoicesCount FROM [T_INVOICE_SUBMISSION_HDR] WHERE [STATUS] = 'Completed';
# Human: what is the total invoice count in last 3 months ?

# %%
# Chain -> above steps + conversation history 

from langchain.memory import ChatMessageHistory
history = ChatMessageHistory()

generate_query = create_sql_query_chain(llm, db,final_prompt)

chain = (
RunnablePassthrough.assign(table_names_to_use=select_table) |
RunnablePassthrough.assign(query=generate_query | RunnableLambda(clean_sql_query)).assign(
    result=itemgetter("query") | execute_query
)
| rephrase_answer
)

# %%
# Testing above code

question = "what is the total invoice count in last 3 months ?"

response = chain.invoke({"question": question,"messages":history.messages, "table_details":table_details})
response
# Out:
# 'The total invoice count in the last 3 months is 1,653.'

# %%
# add conversation history 

history.add_user_message(question)
history.add_ai_message(response)

# %%
# Print conversation history 

history.messages
# Out:
# [HumanMessage(content='what is the total invoice count in last 3 months ?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='The total invoice count in the last 3 months is 1,653.', additional_kwargs={}, response_metadata={})]

# %%
#test 2

question = "what is the total invoice count in last 2 months ?"

response = chain.invoke({"question": question,"messages":history.messages, "table_details":table_details})
response
# Out:
# 'The total invoice count in the last 2 months is 1018.'

# %%
# Print conversation history 

history.messages
# Out:
# [HumanMessage(content='what is the total invoice count in last 3 months ?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='The total invoice count in the last 3 months is 1,653.', additional_kwargs={}, response_metadata={})]

# %%
# add conversation history 

history.add_user_message(question)
history.add_ai_message(response)

# %%
# Print conversation history 

history.messages
# Out:
# [HumanMessage(content='what is the total invoice count in last 3 months ?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='The total invoice count in the last 3 months is 1,653.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='what is the total invoice count in last 2 months ?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='The total invoice count in the last 2 months is 1018.', additional_kwargs={}, response_metadata={})]

# %%
#test 3

question = "1 month?"

response = chain.invoke({"question": question,"messages":history.messages, "table_details":table_details})
response
# Out:
# 'The answer to your question "1 month?" is that there were a total of 298 invoices submitted in the last month.'

# %%
#test 3 verification

question = "what is the total invoice count in last 1 month ?"

response = chain.invoke({"question": question,"messages":history.messages, "table_details":table_details})
response
# Out:
# 'The total invoice count in the last 1 month is 298.'
